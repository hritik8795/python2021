# %%
import matplotlib.pyplot as plt
x=[2,5,8,9,3,6]
y=[2,8,5,2,4,5]

plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel('y-axis')
plt.title('plot')
plt.show()

# %%
import matplotlib.pyplot as plt

x= [1,2,3,4]
y= [1,2,3,4]

plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('frist graph')
plt.show()
